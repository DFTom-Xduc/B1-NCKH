# %% [markdown]
# #MedViTV2
#
# For training and evaluating the model, it is recommended to use a GPU due to the high computational requirements.

# %%
# !nvidia-smi
# Out:
# Sun Sep 20 10:32:38 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install torch==2.8.0 torchvision==0.23.0 --index-url https://download.pytorch.org/whl/cu128
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu128
# Collecting torch==2.8.0
#   Downloading https://download-r2.pytorch.org/whl/cu128/torch-2.8.0%2Bcu128-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchvision==0.23.0
#   Downloading https://download-r2.pytorch.org/whl/cu128/torchvision-0.23.0%2Bcu128-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (4.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (12.8.90)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch==2.8.0)
#   Downloading https://pypi.nvidia.com/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 54.6 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (0.7.1)
# Collecting nvidia-nccl-cu12==2.27.3 (from torch==2.8.0)
#   Downloading https://pypi.nvidia.com/nvidia-nccl-cu12/nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 82.7 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.13/dist-packages (from torch==2.8.0) (1.13.1.3)
# Collecting triton==3.4.0 (from torch==2.8.0)
#   Downloading https://download-r2.pytorch.org/whl/triton-3.4.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from torchvision==0.23.0) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from torchvision==0.23.0) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch==2.8.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch==2.8.0) (3.0.3)
# Downloading https://download-r2.pytorch.org/whl/cu128/torch-2.8.0%2Bcu128-cp313-cp313-manylinux_2_28_x86_64.whl (889.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 889.1/889.1 MB 1.4 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/cu128/torchvision-0.23.0%2Bcu128-cp313-cp313-manylinux_2_28_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 96.3 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/triton-3.4.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 7.5 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nccl-cu12, nvidia-cudnn-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.28.9
#     Uninstalling nvidia-nccl-cu12-2.28.9:
#       Successfully uninstalled nvidia-nccl-cu12-2.28.9
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.19.0.56
#     Uninstalling nvidia-cudnn-cu12-9.19.0.56:
#       Successfully uninstalled nvidia-cudnn-cu12-9.19.0.56
#   Attempting uninstall: torch
#     Found existing installation: torch 2.11.0+cu128
#     Uninstalling torch-2.11.0+cu128:
#       Successfully uninstalled torch-2.11.0+cu128
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.26.0+cu128
#     Uninstalling torchvision-0.26.0+cu128:
#       Successfully uninstalled torchvision-0.26.0+cu128
# Successfully installed nvidia-cudnn-cu12-9.10.2.21 nvidia-nccl-cu12-2.27.3 torch-2.8.0+cu128 torchvision-0.23.0+cu128 triton-3.4.0

# %%
import torch; print(torch.__version__)
# Out:
# 2.8.0+cu128

# %%
# !pip install natten==0.21.1+torch280cu126 -f https://whl.natten.org
# Out:
# Looking in links: https://whl.natten.org
# Collecting natten==0.21.1+torch280cu126
#   Downloading https://github.com/SHI-Labs/NATTEN/releases/download/v0.21.1/natten-0.21.1%2Btorch280cu126-cp313-cp313-linux_x86_64.whl (221.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.4/221.4 MB 6.2 MB/s eta 0:00:00
# Installing collected packages: natten
# Successfully installed natten-0.21.1+torch280cu126

# %% [markdown]
# To get started, clone the repository and navigate to the project directory:

# %%
# !git clone https://github.com/Omid-Nejati/MedViTV2.git
# %cd /content/MedViTV2
# Out:
# Cloning into 'MedViTV2'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 195 (delta 58), reused 28 (delta 26), pack-reused 112 (from 1)
# Receiving objects: 100% (195/195), 3.87 MiB | 29.12 MiB/s, done.
# Resolving deltas: 100% (70/70), done.
# /content/MedViTV2

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: einops in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: timm in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 2)) (1.0.29)
# Collecting medmnist==3.0.2 (from -r requirements.txt (line 3))
#   Downloading medmnist-3.0.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 7)) (0.25.2)
# Collecting fvcore (from -r requirements.txt (line 8))
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 9)) (4.67.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 10)) (11.3.0)
# Collecting fire (from -r requirements.txt (line 11))
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting torchattacks (from -r requirements.txt (line 12))
#   Downloading torchattacks-3.5.1-py3-none-any.whl.metadata (927 bytes)
# Requirement already satisfied: torch in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 13)) (2.8.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 14)) (0.23.0+cu128)
# Collecting grad-cam (from -r requirements.txt (line 15))
#   Downloading grad_cam-1.5.7.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from timm->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.13/dist-packages (from timm->-r requirements.txt (line 2)) (1.29.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.13/dist-packages (from timm->-r requirements.txt (line 2)) (0.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->-r requirements.txt (line 5)) (2026.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.13/dist-packages (from scikit-image->-r requirements.txt (line 7)) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.13/dist-packages (from scikit-image->-r requirements.txt (line 7)) (2.37.4)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.13/dist-packages (from scikit-image->-r requirements.txt (line 7)) (2026.8.23)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.13/dist-packages (from scikit-image->-r requirements.txt (line 7)) (26.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.13/dist-packages (from scikit-image->-r requirements.txt (line 7)) (0.5)
# Collecting yacs>=0.1.6 (from fvcore->-r requirements.txt (line 8))
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.13/dist-packages (from fvcore->-r requirements.txt (line 8)) (3.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.13/dist-packages (from fvcore->-r requirements.txt (line 8)) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore->-r requirements.txt (line 8))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting requests~=2.25.1 (from torchattacks->-r requirements.txt (line 12))
#   Downloading requests-2.25.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (4.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 13)) (3.4.0)
# Collecting ttach (from grad-cam->-r requirements.txt (line 15))
#   Downloading ttach-0.0.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.13/dist-packages (from grad-cam->-r requirements.txt (line 15)) (5.0.0.93)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from grad-cam->-r requirements.txt (line 15)) (3.10.0)
# Collecting portalocker (from iopath>=0.1.7->fvcore->-r requirements.txt (line 8))
#   Downloading portalocker-4.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 5)) (1.17.0)
# Collecting chardet<5,>=3.0.2 (from requests~=2.25.1->torchattacks->-r requirements.txt (line 12))
#   Downloading chardet-4.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting idna<3,>=2.5 (from requests~=2.25.1->torchattacks->-r requirements.txt (line 12))
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting urllib3<1.27,>=1.21.1 (from requests~=2.25.1->torchattacks->-r requirements.txt (line 12))
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests~=2.25.1->torchattacks->-r requirements.txt (line 12)) (2026.7.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch->-r requirements.txt (line 13)) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->grad-cam->-r requirements.txt (line 15)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->grad-cam->-r requirements.txt (line 15)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->grad-cam->-r requirements.txt (line 15)) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->grad-cam->-r requirements.txt (line 15)) (1.5.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->grad-cam->-r requirements.txt (line 15)) (3.3.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 2)) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 2)) (0.16.0)
# Downloading medmnist-3.0.2-py3-none-any.whl (25 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 13.9 MB/s eta 0:00:00
# Downloading torchattacks-3.5.1-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 15.9 MB/s eta 0:00:00
# Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.5 MB/s eta 0:00:00
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 16.0 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.8 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 10.2 MB/s eta 0:00:00
# Downloading portalocker-4.4.0-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 15.6 MB/s eta 0:00:00
# Building wheels for collected packages: fvcore, grad-cam, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61447 sha256=c5ba32658eb7d51cbe814cfe57428e887168ac45aaeeb140be32fef67535a7fa
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/9a/9f4843148961a522f56dbeaa5543071ac2389d9a079ec724ab
#   Building wheel for grad-cam (pyproject.toml) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.5.7-py3-none-any.whl size=53345 sha256=a69a655c8bdf0a8f82027bd5cf5e65854f5c7ea25c029714e4859c3a9ebf0c73
#   Stored in directory: /root/.cache/pip/wheels/91/36/f0/c2367865493d51b13369769181beca14603d17d6539a5922e3
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31596 sha256=31b9e00da8de332198bc9b8e813946e75c1f5cdb7938d59f3123bf743b167f1e
#   Stored in directory: /root/.cache/pip/wheels/cd/c4/19/776124f304c8d9cb940cb164ec2ad635b42d9d1cf03217506d
# Successfully built fvcore grad-cam iopath
# Installing collected packages: yacs, urllib3, ttach, portalocker, idna, fire, chardet, requests, iopath, fvcore, torchattacks, medmnist, grad-cam
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.19
#     Uninstalling idna-3.19:
#       Successfully uninstalled idna-3.19
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.25.1 which is incompatible.
# bigframes 2.48.0 requires requests>=2.27.1, but you have requests 2.25.1 which is incompatible.
# google-genai 2.12.1 requires requests<3.0.0,>=2.28.1, but you have requests 2.25.1 which is incompatible.
# blobfile 3.3.0 requires urllib3>=2, but you have urllib3 1.26.20 which is incompatible.
# sphinx 8.2.3 requires requests>=2.30.0, but you have requests 2.25.1 which is incompatible.
# httpx2 2.12.0 requires idna>=3.18, but you have idna 2.10 which is incompatible.
# datasets 4.8.5 requires requests>=2.32.2, but you have requests 2.25.1 which is incompatible.
# pysal 25.7 requires requests>=2.27, but you have requests 2.25.1 which is incompatible.
# yfinance 0.2.66 requires requests>=2.31, but you have requests 2.25.1 which is incompatible.
# libpysal 4.14.1 requires requests>=2.32.0, but you have requests 2.25.1 which is incompatible.
# tweepy 4.17.0 requires requests<3,>=2.27.0, but you have requests 2.25.1 which is incompatible.
# google-adk 2.7.1 requires requests<3,>=2.32.4, but you have requests 2.25.1 which is incompatible.
# Successfully installed chardet-4.0.0 fire-0.7.1 fvcore-0.1.5.post20221221 grad-cam-1.5.7 idna-2.10 iopath-0.1.10 medmnist-3.0.2 portalocker-4.4.0 requests-2.25.1 torchattacks-3.5.1 ttach-0.0.3 urllib3-1.26.20 yacs-0.1.8

# %% [markdown]
# ### 🧠 Train Different Versions of MedViT on 17 Datasets
#
# You can easily train different versions of MedViT by specifying the model and dataset names:
#
#  🔹 **Model Selection:**
# ```bash
# --model_name [MedViT_tiny, MedViT_small, MedViT_base, MedViT_large]

# %% [markdown]
#
#
#  📊 **Dataset Selection:**
# ```bash
# --dataset [tissuemnist, pathmnist, chestmnist, dermamnist, octmnist,
#            pneumoniamnist, retinamnist, breastmnist, bloodmnist,
#            organamnist, organcmnist, organsmnist, Kvasir, CPN,
#            Fetal, PAD, ISIC2018]

# %% [markdown]
# !!!! The process of downloading the dataset for the first time may take a while, so please be patient. 😊

# %%
# !python main.py --model_name 'MedViT_large' --dataset 'breastmnist' --pretrained False
# Out:
# /usr/local/lib/python3.13/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.13/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Using cuda:0 device.
# Number of channels:  1
# Number of classes:  2
# initialize_weights...
# Dataset BreastMNIST of size 224 (breastmnist_224)
#     Number of datapoints: 546
#     Root location: ./data
#     Split: train
#     Task: binary-class
#     Number of channels: 1
#     Meaning of labels: {'0': 'malignant', '1': 'normal, benign'}
#     Number of samples: {'train': 546, 'val': 78, 'test': 156}
#     Description: The BreastMNIST is based on a dataset of 780 breast ultrasound images. It is categorized into 3 classes: normal, benign, and malignant. As we use low-resolution images, we simplify the task into binary classification by combining normal and benign as positive and classifying them against malignant as negative. We split the source dataset with a ratio of 7:1:2 into training, validation and test set. The source images of 1×500×500 are resized into 1×28×28.
#     License: CC BY 4.0
# ===================
# Dataset BreastMNIST of size 224 (breastmnist_224)
#     Number of datapoints: 156
#     Root location: ./data
#     Split: test
#     Task: binary-class
#     Number of channels: 1
#     Meaning of labels: {'0': 'malignant', '1': 'normal, benign'}
#     Number of samples: {'train': 546, 'val': 78, 'test': 156}
#     Description: The BreastMNIST is based on a dataset of 780 breast ultrasound images. It is categorized into 3 classes: normal, benign, and malignant. As we use low-resolution images, we simplify the task into binary classification by combining normal and benign as positive and classifying them against malignant as negative. We split the source dataset with a ratio of 7:1:2 into training, validation and test set. The source images of 1×500×500 are resized into 1×28×28.
#     License: CC BY 4.0
# train epoch[1/100] loss:0.588: 100% 23/23 [00:31<00:00,  1.38s/it]
# 100% 4/4 [00:02<00:00,  1.81it/s]
# [epoch 1] train_loss: 0.680  auc: 0.516  acc: 0.276
#
# Saving checkpoint...
# train epoch[2/100] loss:0.647: 100% 23/23 [00:31<00:00,  1.38s/it]
# 100% 4/4 [00:02<00:00,  1.78it/s]
# [epoch 2] train_loss: 0.657  auc: 0.601  acc: 0.417
#
# Saving checkpoint...
# train epoch[3/100] loss:0.605: 100% 23/23 [00:33<00:00,  1.44s/it]
# 100% 4/4 [00:02<00:00,  1.61it/s]
# [epoch 3] train_loss: 0.657  auc: 0.747  acc: 0.526
#
# Saving checkpoint...
# train epoch[4/100] loss:0.594: 100% 23/23 [00:36<00:00,  1.57s/it]
# 100% 4/4 [00:02<00:00,  1.51it/s]
# [epoch 4] train_loss: 0.630  auc: 0.716  acc: 0.731
# train epoch[5/100] loss:0.593: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.63it/s]
# [epoch 5] train_loss: 0.612  auc: 0.777  acc: 0.801
#
# Saving checkpoint...
# train epoch[6/100] loss:0.553: 100% 23/23 [00:35<00:00,  1.55s/it]
# 100% 4/4 [00:02<00:00,  1.47it/s]
# [epoch 6] train_loss: 0.601  auc: 0.766  acc: 0.750
# train epoch[7/100] loss:0.640: 100% 23/23 [00:35<00:00,  1.54s/it]
# 100% 4/4 [00:02<00:00,  1.63it/s]
# [epoch 7] train_loss: 0.606  auc: 0.788  acc: 0.763
#
# Saving checkpoint...
# train epoch[8/100] loss:0.785: 100% 23/23 [00:35<00:00,  1.52s/it]
# 100% 4/4 [00:02<00:00,  1.49it/s]
# [epoch 8] train_loss: 0.606  auc: 0.727  acc: 0.756
# train epoch[9/100] loss:0.532: 100% 23/23 [00:35<00:00,  1.54s/it]
# 100% 4/4 [00:02<00:00,  1.65it/s]
# [epoch 9] train_loss: 0.579  auc: 0.768  acc: 0.750
# train epoch[10/100] loss:0.620: 100% 23/23 [00:34<00:00,  1.51s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 10] train_loss: 0.564  auc: 0.776  acc: 0.763
# train epoch[11/100] loss:0.677: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 11] train_loss: 0.561  auc: 0.823  acc: 0.782
#
# Saving checkpoint...
# train epoch[12/100] loss:0.687: 100% 23/23 [00:35<00:00,  1.54s/it]
# 100% 4/4 [00:02<00:00,  1.48it/s]
# [epoch 12] train_loss: 0.561  auc: 0.769  acc: 0.827
# train epoch[13/100] loss:0.466: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.64it/s]
# [epoch 13] train_loss: 0.535  auc: 0.808  acc: 0.782
# train epoch[14/100] loss:0.572: 100% 23/23 [00:34<00:00,  1.51s/it]
# 100% 4/4 [00:02<00:00,  1.57it/s]
# [epoch 14] train_loss: 0.547  auc: 0.787  acc: 0.731
# train epoch[15/100] loss:0.455: 100% 23/23 [00:35<00:00,  1.55s/it]
# 100% 4/4 [00:02<00:00,  1.59it/s]
# [epoch 15] train_loss: 0.538  auc: 0.800  acc: 0.756
# train epoch[16/100] loss:0.710: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.59it/s]
# [epoch 16] train_loss: 0.525  auc: 0.778  acc: 0.750
# train epoch[17/100] loss:0.438: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.55it/s]
# [epoch 17] train_loss: 0.521  auc: 0.822  acc: 0.782
# train epoch[18/100] loss:0.377: 100% 23/23 [00:34<00:00,  1.52s/it]
# 100% 4/4 [00:02<00:00,  1.60it/s]
# [epoch 18] train_loss: 0.518  auc: 0.792  acc: 0.846
# train epoch[19/100] loss:0.606: 100% 23/23 [00:34<00:00,  1.51s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 19] train_loss: 0.527  auc: 0.796  acc: 0.814
# train epoch[20/100] loss:0.632: 100% 23/23 [00:35<00:00,  1.54s/it]
# 100% 4/4 [00:02<00:00,  1.57it/s]
# [epoch
 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 75] train_loss: 0.432  auc: 0.893  acc: 0.833
# train epoch[76/100] loss:0.568: 100% 23/23 [00:34<00:00,  1.52s/it]
# 100% 4/4 [00:02<00:00,  1.59it/s]
# [epoch 76] train_loss: 0.465  auc: 0.875  acc: 0.840
# train epoch[77/100] loss:0.455: 100% 23/23 [00:34<00:00,  1.51s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 77] train_loss: 0.437  auc: 0.888  acc: 0.833
# train epoch[78/100] loss:0.334: 100% 23/23 [00:34<00:00,  1.52s/it]
# 100% 4/4 [00:02<00:00,  1.60it/s]
# [epoch 78] train_loss: 0.464  auc: 0.887  acc: 0.814
# train epoch[79/100] loss:0.612: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 79] train_loss: 0.437  auc: 0.860  acc: 0.814
# train epoch[80/100] loss:0.492: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 80] train_loss: 0.427  auc: 0.888  acc: 0.833
# train epoch[81/100] loss:0.437: 100% 23/23 [00:34<00:00,  1.52s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 81] train_loss: 0.436  auc: 0.853  acc: 0.827
# train epoch[82/100] loss:0.417: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.59it/s]
# [epoch 82] train_loss: 0.443  auc: 0.869  acc: 0.833
# train epoch[83/100] loss:0.429: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 83] train_loss: 0.414  auc: 0.872  acc: 0.827
# train epoch[84/100] loss:0.629: 100% 23/23 [00:35<00:00,  1.54s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 84] train_loss: 0.440  auc: 0.886  acc: 0.853
# train epoch[85/100] loss:0.301: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 85] train_loss: 0.404  auc: 0.886  acc: 0.846
# train epoch[86/100] loss:0.380: 100% 23/23 [00:35<00:00,  1.54s/it]
# 100% 4/4 [00:02<00:00,  1.59it/s]
# [epoch 86] train_loss: 0.407  auc: 0.890  acc: 0.827
# train epoch[87/100] loss:0.420: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 87] train_loss: 0.443  auc: 0.878  acc: 0.821
# train epoch[88/100] loss:0.387: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.59it/s]
# [epoch 88] train_loss: 0.419  auc: 0.881  acc: 0.827
# train epoch[89/100] loss:0.617: 100% 23/23 [00:35<00:00,  1.55s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 89] train_loss: 0.420  auc: 0.854  acc: 0.821
# train epoch[90/100] loss:0.354: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.56it/s]
# [epoch 90] train_loss: 0.425  auc: 0.866  acc: 0.808
# train epoch[91/100] loss:0.463: 100% 23/23 [00:35<00:00,  1.54s/it]
# 100% 4/4 [00:02<00:00,  1.56it/s]
# [epoch 91] train_loss: 0.402  auc: 0.885  acc: 0.821
# train epoch[92/100] loss:0.583: 100% 23/23 [00:35<00:00,  1.54s/it]
# 100% 4/4 [00:02<00:00,  1.55it/s]
# [epoch 92] train_loss: 0.427  auc: 0.866  acc: 0.814
# train epoch[93/100] loss:0.541: 100% 23/23 [00:35<00:00,  1.52s/it]
# 100% 4/4 [00:02<00:00,  1.56it/s]
# [epoch 93] train_loss: 0.406  auc: 0.892  acc: 0.827
# train epoch[94/100] loss:0.475: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.57it/s]
# [epoch 94] train_loss: 0.407  auc: 0.887  acc: 0.827
# train epoch[95/100] loss:0.691: 100% 23/23 [00:35<00:00,  1.54s/it]
# 100% 4/4 [00:02<00:00,  1.56it/s]
# [epoch 95] train_loss: 0.410  auc: 0.888  acc: 0.833
# train epoch[96/100] loss:0.249: 100% 23/23 [00:35<00:00,  1.52s/it]
# 100% 4/4 [00:02<00:00,  1.56it/s]
# [epoch 96] train_loss: 0.433  auc: 0.888  acc: 0.853
# train epoch[97/100] loss:0.415: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 97] train_loss: 0.422  auc: 0.871  acc: 0.821
# train epoch[98/100] loss:0.660: 100% 23/23 [00:35<00:00,  1.54s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 98] train_loss: 0.436  auc: 0.873  acc: 0.814
# train epoch[99/100] loss:0.400: 100% 23/23 [00:35<00:00,  1.53s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 99] train_loss: 0.424  auc: 0.880  acc: 0.821
# train epoch[100/100] loss:0.258: 100% 23/23 [00:35<00:00,  1.52s/it]
# 100% 4/4 [00:02<00:00,  1.58it/s]
# [epoch 100] train_loss: 0.409  auc: 0.869  acc: 0.846
# Finished Training

# %% [markdown]
# ###Train timm models
# 🤯 You can easily train any model from TIMM on each dataset by simply changing the model name. If a pre-trained version is available, you can enable it by setting the corresponding flag to True.
#
# link: https://timm.fast.ai/

# %%
# !python main.py --model_name 'resnet34' --dataset 'octmnist' --pretrained True
